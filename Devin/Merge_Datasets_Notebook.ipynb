# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read the data

# %%
social_total = pd.read_csv('social_total.csv')

# %%
economic_draft = pd.read_csv('economic_draft.csv')

# %%
state = pd.read_csv('state-abbrevs.csv')

# %% [markdown]
# Clean the data and add new columns:
# 1. Use a regular expression to extract the congressional district number
# 2. Fill (at-large) districts with 0
# 3. Extract the state from the geographic name column using regular expressions
# 4. Strip the extra space out of the state column

# %%
social_total['district'] = social_total.NAME.str.extract('(\d+)(....\d)')[0]
social_total['district']= social_total.district.fillna('0')
social_total['state'] = social_total.NAME.str.extract('[^,]*,(.*)')[0]
social_total['state'] = [x.strip() for x in social_total['state']]

# %% [markdown]
# Merge the economic dataset with the state abbreviations dataset

# %%
social_total = pd.merge(left=social_total, right=state, how='inner', on = 'state')
social_total['state_dist'] = social_total['abbreviation'].astype(str) + '-'+ social_total['district'].astype(str)

# %% [markdown]
# Merge the economic data and social data

# %%
census_merge = pd.merge(left=economic_draft, right=social_total, how='outer', left_on=['state_dist','year'], right_on=['state_dist','year'])

# %% [markdown]
# Drop the NA

# %%
census_merge = census_merge.dropna()

# %% [markdown]
# Read the demographic data

# %%
demographic_total = pd.read_csv('demographic_total.csv')

# %% [markdown]
# Create the state district column

# %%
demographic_total['state_dist'] = demographic_total['state'].astype(str) + '-'+ demographic_total['district'].astype(str)

# %% [markdown]
# Merge the census data and the demographic data

# %%
census_final = pd.merge(left=census_merge, right=demographic_total, how='outer', left_on=['state_dist','year'], right_on=['state_dist','year'])

# %% [markdown]
# Check the data

# %%
census_final
# Out:
#       year                                               name  \
# 0     2014  Congressional District 1 (114th Congress), Ala...
# 1     2014  Congressional District 2 (114th Congress), Ala...
# 2     2014  Congressional District 3 (114th Congress), Ala...
# 3     2014  Congressional District 4 (114th Congress), Ala...
# 4     2014  Congressional District 5 (114th Congress), Ala...
# ...    ...                                                ...
# 1300  2018  Congressional District 6 (116th Congress), Wis...
# 1301  2018  Congressional District 8 (116th Congress), Wis...
# 1302  2014  Congressional District (at Large) (114th Congr...
# 1303  2016  Congressional District (at Large) (115th Congr...
# 1304  2018  Congressional District (at Large) (116th Congr...
#
#       laborforce_employed  laborforce_unemployed  armed_forces_employed  \
# 0                    51.4                    4.7                    0.2
# 1                    51.3                    5.2                    1.2
# 2                    51.9                    5.2                    0.5
# 3                    49.8                    4.1                    0.1
# 4                    56.2                    4.6                    0.2
# ...                   ...                    ...                    ...
# 1300                 63.1                    2.0                    0.0
# 1301                 64.4                    1.6                    0.0
# 1302                 64.8                    2.9                    0.5
# 1303                 62.6                    3.7                    0.5
# 1304                 62.5                    2.5                    0.8
#
#       unemployment_rate  PercentCar  PercentCarpool  PercentPublicTrans  \
# 0                   8.3        87.3             7.2                 0.4
# 1                   9.2        85.1             9.0                 0.4
# 2                   9.1        86.3             8.4                 0.4
# 3                   7.6        86.1             9.6                 0.3
# 4                   7.6        87.2             6.9                 0.4
# ...                 ...         ...             ...                 ...
# 1300                3.1        84.8             7.1                 0.3
# 1301                2.5        84.8             7.4                 0.4
# 1302                4.3        76.8            11.0                 1.6
# 1303                5.6        77.8             9.0                 1.5
# 1304                3.9        75.8            10.2                 1.2
#
#       Walked  ...  X65_to_74  X75_to_84  X85_over  median_age  white_pct  \
# 0        0.8  ...        9.5        4.8       1.9        39.5       67.2
# 1        1.2  ...        8.9        5.0       1.6        38.0       65.4
# 2        1.2  ...        9.0        4.4       1.6        38.0       69.7
# 3        0.8  ...       10.0        5.3       1.8        40.9       87.3
# 4        1.3  ...        8.6        4.8       1.6        39.4       76.8
# ...      ...  ...        ...        ...       ...         ...        ...
# 1300     2.2  ...       10.5        5.4       2.6        41.9       92.3
# 1301     2.0  ...        9.9        5.3       1.9        40.7       90.0
# 1302     3.6  ...        8.4        4.0       1.4        36.6       91.0
# 1303     4.6  ...        9.2        4.1       1.7        37.2       92.0
# 1304     4.3  ...       10.3        4.8       1.6        38.5       91.5
#
#       black_pct  amer_ind  asian_pct  pac_isl_pct  hispanic_pct
# 0          27.9       0.8        1.4          0.0           3.1
# 1          30.9       0.5        1.1          0.0           3.2
# 2          26.0       0.3        1.4          0.1           3.0
# 3           6.9       0.7        0.5          0.0           6.0
# 4          17.2       0.6        1.4          0.1           5.0
# ...         ...       ...        ...          ...           ...
# 1300        2.1       0.5        2.4          0.0           4.7
# 1301        1.6       2.6        2.1          0.0           5.4
# 1302        1.1       2.6        0.9          0.1           9.8
# 1303        1.0       2.3        1.0          0.1           9.6
# 1304        0.6       2.8        1.0          0.2          10.0
#
# [1305 rows x 83 columns]

# %% [markdown]
# Read in the house elections dataset

# %%
data3 = pd.read_csv("house_elections_final.csv")

# %% [markdown]
# Merge the election data with the census data

# %%
cap_data = pd.merge(left=census_final, right=data3, how='inner', left_on=['state_dist', 'year'], right_on=['state_dist', 'year'])

# %% [markdown]
# Check the results

# %%
cap_data
# Out:
#       year                                               name  \
# 0     2014  Congressional District 1 (114th Congress), Ala...
# 1     2014  Congressional District 2 (114th Congress), Ala...
# 2     2014  Congressional District 3 (114th Congress), Ala...
# 3     2014  Congressional District 4 (114th Congress), Ala...
# 4     2014  Congressional District 5 (114th Congress), Ala...
# ...    ...                                                ...
# 1300  2018  Congressional District 6 (116th Congress), Wis...
# 1301  2018  Congressional District 8 (116th Congress), Wis...
# 1302  2014  Congressional District (at Large) (114th Congr...
# 1303  2016  Congressional District (at Large) (115th Congr...
# 1304  2018  Congressional District (at Large) (116th Congr...
#
#       laborforce_employed  laborforce_unemployed  armed_forces_employed  \
# 0                    51.4                    4.7                    0.2
# 1                    51.3                    5.2                    1.2
# 2                    51.9                    5.2                    0.5
# 3                    49.8                    4.1                    0.1
# 4                    56.2                    4.6                    0.2
# ...                   ...                    ...                    ...
# 1300                 63.1                    2.0                    0.0
# 1301                 64.4                    1.6                    0.0
# 1302                 64.8                    2.9                    0.5
# 1303                 62.6                    3.7                    0.5
# 1304                 62.5                    2.5                    0.8
#
#       unemployment_rate  PercentCar  PercentCarpool  PercentPublicTrans  \
# 0                   8.3        87.3             7.2                 0.4
# 1                   9.2        85.1             9.0                 0.4
# 2                   9.1        86.3             8.4                 0.4
# 3                   7.6        86.1             9.6                 0.3
# 4                   7.6        87.2             6.9                 0.4
# ...                 ...         ...             ...                 ...
# 1300                3.1        84.8             7.1                 0.3
# 1301                2.5        84.8             7.4                 0.4
# 1302                4.3        76.8            11.0                 1.6
# 1303                5.6        77.8             9.0                 1.5
# 1304                3.9        75.8            10.2                 1.2
#
#       Walked  ...  X85_over  median_age  white_pct  black_pct  amer_ind  \
# 0        0.8  ...       1.9        39.5       67.2       27.9       0.8
# 1        1.2  ...       1.6        38.0       65.4       30.9       0.5
# 2        1.2  ...       1.6        38.0       69.7       26.0       0.3
# 3        0.8  ...       1.8        40.9       87.3        6.9       0.7
# 4        1.3  ...       1.6        39.4       76.8       17.2       0.6
# ...      ...  ...       ...         ...        ...        ...       ...
# 1300     2.2  ...       2.6        41.9       92.3        2.1       0.5
# 1301     2.0  ...       1.9        40.7       90.0        1.6       2.6
# 1302     3.6  ...       1.4        36.6       91.0        1.1       2.6
# 1303     4.6  ...       1.7        37.2       92.0        1.0       2.3
# 1304     4.3  ...       1.6        38.5       91.5        0.6       2.8
#
#       asian_pct  pac_isl_pct  hispanic_pct  party  pct_won
# 0           1.4          0.0           3.1      R    68.16
# 1           1.1          0.0           3.2      R    67.34
# 2           1.4          0.1           3.0      R    66.12
# 3           0.5          0.0           6.0      R    98.57
# 4           1.4          0.1           5.0      R    74.42
# ...         ...          ...           ...    ...      ...
# 1300        2.4          0.0           4.7      R    55.47
# 1301        2.1          0.0           5.4      R    63.69
# 1302        0.9          0.1           9.8      R    66.05
# 1303        1.0          0.1           9.6      R    60.35
# 1304        1.0          0.2          10.0      R    63.59
#
# [1305 rows x 85 columns]
